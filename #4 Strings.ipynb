# %% [markdown]
# # **Greeting bot**
#
# `1)Ask for name`\
# `2)Ask for age`\
# `3)Ask for city`\
# `4)Ask for hobby`\
# `5)Output`

# %% [markdown]
# ## **`Note 1`**
# #### **a) If in a string there is a (" ") use (' ') to begin & end**
# #### **b) If in a string there is a (' ') use (" ") to begin & end**
# #### **c) If in a string (" ") & (' ') both are present, use (""") to begin & end**
#
# ## **`Note 2`**
# #### **An input function is always a string.**

# %%
# Ask user for name
name = input("Enter ur name")
# Out:
# Enter ur namesaksham jain

# %%
# Ask user for age
age = input("age")
# Out:
# age20

# %%
# Ask user for their city
city = input("city")
# Out:
# cityDelhi

# %%
# Ask for their hobby
hobby = input("ENter ur hobbies")
# Out:
# ENter ur hobbiessketching

# %%
# Create output
output= "ur name is {} , ur age is {}, ur city is {} & ur hobby is {}".format(name, age, city, hobby)

# %%
name = input("Enter ur name")
age = input("age")
city = input("city")
hobby = input("ENter ur hobbies")
output= "ur name is {} , ur age is {}, ur city is {} & ur hobby is {}".format(name, age, city, hobby)
print(output)
# Out:
# Enter ur nameGoku
# age100
# cityz city
# ENter ur hobbiesfighting
# ur name is Goku , ur age is 100, ur city is z city & ur hobby is fighting

# %% [markdown]
# # **String Methods-1**
#
# ### **`string.method()`**
#
# `Note`
#  *original string is never modified*

# %% [markdown]
# ### **`string.count()`**

# %%
"Hello World 1 2 3".count("l")
# Out:
# 3

# %%
"Hello World 1 2 3".count("L")
# Out:
# 0

# %% [markdown]
# ### **`string.capitalize()`**

# %%
"Hello World 1 2 3".capitalize()
# Out:
# 'Hello world 1 2 3'

# %% [markdown]
# ### **`string.title()`**

# %%
"hello world 1 2 3".title()
# Out:
# 'Hello World 1 2 3'

# %% [markdown]
# ### **`string.lower()`**

# %%
"Hello World 1 2 3 HLFHLFJ:FKJ:DSJDPJS".lower()
# Out:
# 'hello world 1 2 3 hlfhlfj:fkj:dsjdpjs'

# %% [markdown]
# ### **`string.upper()`**

# %%
"Hello World 1 2 3 HLFHLFJ:FKJ:DSJDPJS".upper()
# Out:
# 'HELLO WORLD 1 2 3 HLFHLFJ:FKJ:DSJDPJS'

# %% [markdown]
# # **String Methods-2**
# ### **is check()**

# %%
x= "IamlearningPython"

# %%
# is lower
x.islower()
# Out:
# False

# %%
# is upper
x.isupper()
# Out:
# False

# %%
# is alpha
x.isalpha()
# Out:
# True

# %%
# is alnum
x.isalnum()
# Out:
# True

# %% [markdown]
# # **String methods 3**

# %% [markdown]
# ### `string.index()`

# %%
x= "Happy birthday"

# %%
x.index("birthday")
# Out:
# 6

# %%
x.index("dsadasdsa")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-160f5df09a3a> in <module>()
# ----> 1 x.index("dsadasdsa")
#
# ValueError: substring not found

# %% [markdown]
# ### `string.find()`

# %%
x.find("birthday")
# Out:
# 6

# %%
x.find("dsadsadsadsdadssadsdd")
# Out:
# -1

# %% [markdown]
# ### `string.strip()`

# %%
y = "0000happybirthday0000  "

# %%
y.strip("0")
# Out:
# 'happybirthday'

# %%
y.lstrip("0")
# Out:
# 'happybirthday0000'

# %%
y.rstrip("0")
# Out:
# '0000happybirthday'

# %%
y.strip()
# Out:
# '0000happybirthday0000'
