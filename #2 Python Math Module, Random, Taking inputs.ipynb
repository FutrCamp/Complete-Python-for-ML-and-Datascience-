# %% [markdown]
# # **Math Module**
#
# ### **`import math`**

# %%
import math

# %% [markdown]
# `round`

# %%
round(2.1)
# Out:
# 2

# %%
round(1.5)
# Out:
# 2

# %% [markdown]
# `math.floor`

# %%
math.floor(1.5)
# Out:
# 1

# %% [markdown]
# `math.ceil`

# %%
math.ceil(3.1)
# Out:
# 4

# %% [markdown]
# `math.pi`

# %%
math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# `math.e`

# %%
math.e
# Out:
# 2.718281828459045

# %% [markdown]
# `math.sin()`

# %%
math.sin(math.pi/2)
# Out:
# 1.0

# %%
math.sin(0)
# Out:
# 0.0

# %% [markdown]
# `math.cos()`

# %%
math.cos(0)
# Out:
# 1.0

# %% [markdown]
# `math.asin()`

# %%
math.asin(0)
# Out:
# 0.0

# %% [markdown]
# `math.acos()`

# %%
math.acos(0)
# Out:
# 1.5707963267948966

# %% [markdown]
# `math.hypot()`

# %%
math.hypot(3,4)
# Out:
# 5.0

# %% [markdown]
# `math.pow()`

# %%
math.pow(2,3)
# Out:
# 8.0

# %% [markdown]
# `x**y`

# %%
3**3
# Out:
# 27

# %% [markdown]
# `math.exp()`

# %%
math.exp(2)
# Out:
# 7.38905609893065

# %% [markdown]
# `math.log()`

# %%
math.log(math.e)
# Out:
# 1.0

# %% [markdown]
# # **random**
#
# ### `import random`

# %% [markdown]
# ### Crafting a Health Potion

# %%
import random
health=50
difficulty=100
potion_health= random.randint(20,50)/difficulty
health= health + potion_health
print(health)
# Out:
# 50.46

# %% [markdown]
# # **Taking input from a user**

# %%
name = input("Please enter your name")
print(name)
# Out:
# Please enter your namesj
# sj

# %%
print(name)
# Out:
# sj
