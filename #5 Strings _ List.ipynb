# %% [markdown]
# # **String indexing**

# %%
s= "Hello World"

# %%
# first letter
s[0]
# Out:
# 'H'

# %%
# 2nd letter
s[1]
# Out:
# 'e'

# %%
# last letter
s[-1]
# Out:
# 'd'

# %%
# Grab everything UP TO the 3rd index
s[:3]
# Out:
# 'Hel'

# %%
# Grab everything past the first term all the way to the length of s which is len(s)
s[1:]
# Out:
# 'ello World'

# %%
#Everything
s[0:]
# Out:
# 'Hello World'

# %%
# Grab everything but the last letter
s[:-1]
# Out:
# 'Hello Worl'

# %%
# Note that there is no change to the original s
s
# Out:
# 'Hello World'

# %%
# Grab everything, but go in steps size of 1
s[::1]
# Out:
# 'Hello World'

# %%
# Grab everything, but go in step sizes of 2
s[::2]
# Out:
# 'HloWrd'

# %%
# We can use this to print a string backwards
s[::-1]
# Out:
# 'dlroW olleH'

# %% [markdown]
# Concatenating strings

# %%
s = s + "concatenate me please!"
print(s)
# Out:
# Hello World concatenate me please! concatenate me please!concatenate me please!

# %% [markdown]
# Using multiplication to create repetition

# %%
x= 'a'
x*11
# Out:
# 'aaaaaaaaaaa'

# %% [markdown]
# # **List basics**

# %%
mylist= [27,46,-5,17.2]
print(mylist)
# Out:
# [27, 46, -5, 17.2]

# %%
type(mylist)
# Out:
# list

# %%
sam = ["a","b","C",1,2,3,"do",56,78]

# %%
sam[3]
# Out:
# 1

# %%
sam[7]
# Out:
# 56

# %%
our_list= [1,2,[3,4,5],6,7,8]

# %%
our_list[2]
# Out:
# [3, 4, 5]

# %%
our_list[2][1]
# Out:
# 4

# %%
our_list[2][1:]
# Out:
# [4, 5]
